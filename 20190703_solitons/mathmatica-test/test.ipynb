# %%
JupyterImageResolution = 84;
JupyterOutTextForm = "TeX";

TeX[x_] := ToString[TeXForm[x]]

# %%
D[D[f[x],x],x] //TeX
# Out:
# <div>$$&#102;&#39;&#39;&#40;&#120;&#41;$$</div>

# %%
Series[f[x, y], {x, x0, 2}, {y, y0, 2}] //TeX
# Out:
# <div>$$&#92;&#108;&#101;&#102;&#116;&#40;&#102;&#40;&#92;&#116;&#101;&#120;&#116;&#123;&#120;&#48;&#125;&#44;&#92;&#116;&#101;&#120;&#116;&#123;&#121;&#48;&#125;&#41;&#43;&#40;&#121;&#45;&#92;&#116;&#101;&#120;&#116;&#123;&#121;&#48;&#125;&#41;&#32;&#102;&#94;&#123;&#40;&#48;&#44;&#49;&#41;&#125;&#40;&#92;&#116;&#101;&#120;&#116;&#123;&#120;&#48;&#125;&#44;&#92;&#116;&#101;&#120;&#116;&#123;&#121;&#48;&#125;&#41;&#43;&#92;&#102;&#114;&#97;&#99;&#123;&#49;&#125;&#123;&#50;&#125;&#32;&#40;&#121;&#45;&#92;&#116;&#101;&#120;&#116;&#123;&#121;&#48;&#125;&#41;&#94;&#50;&#32;&#102;&#94;&#123;&#40;&#48;&#44;&#50;&#41;&#125;&#40;&#92;&#116;&#101;&#120;&#116;&#123;&#120;&#48;&#125;&#44;&#92;&#116;&#101;&#120;&#116;&#123;&#121;&#48;&#125;&#41;&#43;&#79;&#92;&#108;&#101;&#102;&#116;&#40;&#40;&#121;&#45;&#92;&#116;&#101;&#120;&#116;&#123;&#121;&#48;&#125;&#41;&#94;&#51;&#92;&#114;&#105;&#103;&#104;&#116;&#41;&#92;&#114;&#105;&#103;&#104;&#116;&#41;&#43;&#40;&#120;&#45;&#92;&#116;&#101;&#120;&#116
# ...

# %%
Exp[Sum[2*k^j*y[j],{j,1,Infinity}]]
# Out:
# <div><img alt="Output" src="data:image/png;base64,..." width="90"></div>

# %%
Sum[2*k^j*y[j],{j,1,Infinity}]
# Out:
# <div><img alt="Output" src="data:image/png;base64,..." width="91"></div>

# %%
Replace[x->1/y][Sum[x^n/n!,{n,0,Infinity}]] //TeX
# Out:
# <div>$$&#101;&#94;&#120;$$</div>

# %%
Replace[x^2 -> a + b][x^2]
# Out:
# <div><img alt="Output" src="data:image/png;base64,..." width="34"></div>

# %%
a=Sum[x^n/n!,{n,0,Infinity}] /.x->Sum[2*k^j*y[j]+(y[j]-1/(j*k^j))*d[j],{j,1,3}]
# Out:
# <div><img alt="Output" src="data:image/png;base64,..." width="500"></div>

# %%
a/.y[2]->0/.y[3]->0
# Out:
# <div><img alt="Output" src="data:image/png;base64,..." width="232"></div>

# %%
Series[a,{y[1],0,10}]
# Out:
# <div><img alt="Output" src="data:image/png;base64,..." width="1165"></div>

# %%
Coefficient[Series[a,{y[1],0,10}],k] //TeX
# Out:
# <div>$$&#92;&#102;&#114;&#97;&#99;&#123;&#100;&#40;&#49;&#41;&#94;&#57;&#32;&#121;&#40;&#49;&#41;&#94;&#123;&#49;&#48;&#125;&#32;&#92;&#101;&#120;&#112;&#32;&#92;&#108;&#101;&#102;&#116;&#40;&#100;&#40;&#51;&#41;&#32;&#92;&#108;&#101;&#102;&#116;&#40;&#121;&#40;&#51;&#41;&#45;&#92;&#102;&#114;&#97;&#99;&#123;&#49;&#125;&#123;&#51;&#32;&#107;&#94;&#51;&#125;&#92;&#114;&#105;&#103;&#104;&#116;&#41;&#43;&#100;&#40;&#50;&#41;&#32;&#92;&#108;&#101;&#102;&#116;&#40;&#121;&#40;&#50;&#41;&#45;&#92;&#102;&#114;&#97;&#99;&#123;&#49;&#125;&#123;&#50;&#32;&#107;&#94;&#50;&#125;&#92;&#114;&#105;&#103;&#104;&#116;&#41;&#45;&#92;&#102;&#114;&#97;&#99;&#123;&#100;&#40;&#49;&#41;&#125;&#123;&#107;&#125;&#43;&#50;&#32;&#107;&#94;&#51;&#32;&#121;&#40;&#51;&#41;&#43;&#50;&#32;&#107;&#94;&#50;&#32;&#121;&#40;&#50;&#41;&#92;&#114;&#105;&#103;&#104;&#116;&#41;&#125;&#123;&#49;&#56;&#49;&#52;&#52;&#48;&#125;&#43;&#92;&#102;&#114;&#97;&#99;&#123;&#100;&#40;&#49;&#41;&#94;&#56;&#32;&#121;&#40;&#49;&#41;&#94;&
# ...

# %%
For[i = 0, i < 4, i++, Print[{i}]]
# Out:
# {0}
# {1}
# {2}
# {3}

# %%
data = Table[i + j, {i, 1, 5}, {j, 1, 4}]
# Out:
# <div>$$&#123;&#123;&#50;&#44;&#32;&#51;&#44;&#32;&#52;&#44;&#32;&#53;&#125;&#44;&#32;&#123;&#51;&#44;&#32;&#52;&#44;&#32;&#53;&#44;&#32;&#54;&#125;&#44;&#32;&#123;&#52;&#44;&#32;&#53;&#44;&#32;&#54;&#44;&#32;&#55;&#125;&#44;&#32;&#123;&#53;&#44;&#32;&#54;&#44;&#32;&#55;&#44;&#32;&#56;&#125;&#44;&#32;&#123;&#54;&#44;&#32;&#55;&#44;&#32;&#56;&#44;&#32;&#57;&#125;&#125;$$</div>

# %%
MatrixForm[data]
# Out:
# <div><img alt="Output" src="data:image/png;base64,..." width="92"></div>

# %%
ListLinePlot[data, AxesOrigin -> {0, 0}]
# Out:
# <div><img alt="Output" src="data:image/png;base64,..." width="420"></div>
